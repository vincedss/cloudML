# %%
# %pylab inline

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd

# %%
# Example: load a DSS dataset as a Pandas dataframe
mydataset = dataiku.Dataset("mydataset")
mydataset_df = mydataset.get_dataframe()

# %%
c = dataiku.api_client()

# %%
c.list_global_api_keys()
# Out:
# [{u'adminProperties': {},
#   u'clusters': {},
#   u'codeEnvs': {},
#   u'createdBy': u'cli-dsscli',
#   u'createdOn': 1538472160691,
#   u'execSQLLike': False,
#   u'globalPermissions': {u'admin': True,
#    u'mayCreateAuthenticatedConnections': False,
#    u'mayCreateClusters': False,
#    u'mayCreateCodeEnvs': False,
#    u'mayCreateProjects': False,
#    u'mayCreatePublishedAPIServices': False,
#    u'mayDevelopPlugins': False,
#    u'mayEditLibFolders': False,
#    u'mayManageClusters': False,
#    u'mayManageCodeEnvs': False,
#    u'mayManageUDM': False,
#    u'mayViewIndexedHiveConnections': False,
#    u'mayWriteSafeCode': False,
#    u'mayWriteUnsafeCode': False},
#   u'id': u'74FHL9YC59MU6JG0',
#   u'key': u'C12TMW41P5COTCHY4RFCH728BPZ1DJC7',
#   u'label': u'Key generated by dsscli',
#   u'projects': {},
#   u'unscopedDatasets': [],
#   u'userProperties': {}},
#  {u'adminProperties': {},
#   u'clusters': {},
#   u'codeEnvs': {},
#   u'createdOn': 1538472161222,
#   u'description': u'',
#   u'execSQLLike': False,
#   u'globalPermissions': {u'admin': True,
#    u'mayCreateAuthenticatedConnections': False,
#    u'mayCreateClusters': False,
#    u'mayCreateCodeEnvs': False,
#    u'mayCreateProjects': False,
#    u'mayCreatePublishedAPIServices': False,
#    u'mayDevelopPlugins': False,
#    u'mayEditLibFolders': False,
#    u'mayManageClusters': False,
#    u'mayManageCodeEnvs': False,
#    u'mayManageUDM': False,
#    u'mayViewIndexedHiveConnections': False,
#    u'mayWriteSafeCode': False,
#    u'mayWriteUnsafeCode': False},
#   u'id': u'RAGV0UQG5qjJowHo',
#   u'key': u'Jm4AoD2cpLP4bWfaEmxciO6i34koK3EJ',
#   u'label': u'ansible-admin-key',
#   u'projects': {},
#   u'unscopedDatasets': [],
#   u'userProperties': {}}]
