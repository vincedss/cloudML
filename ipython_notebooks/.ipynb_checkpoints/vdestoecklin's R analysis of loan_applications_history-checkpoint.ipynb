# %%
library(dataiku)

# %%
library(RJSONIO)

# %%
# Read the dataset as a R dataframe in memory
# Note: here, we only read the first 100K rows. Other sampling options are available
df <- dkuReadDataset("loan_applications_history", samplingMethod="head", nbRows=100000)

# %%
head(df)
# Out:
#   loan_amnt funded_amnt funded_amnt_inv term      int_rate installment grade
# 1 10000     10000        9900.000       36 months 6.17%    305.00      A
# 2 25000     25000       24850.000       36 months 11.12%   819.89      B
# 3 15000     15000        2324.993       36 months 11.58%   495.21      B
# 4  5800      5800        5800.000       36 months 7.29%    179.86      A
# 5 20675     20675       20625.000       60 months 12.99%   470.32      C
# 6 10000      6800        3599.999       60 months 13.98%   158.16      C
#   sub_grade issue_date zip_code ⋯ emp_length home_ownership annual_inc
# 1 A3        Nov-2010   720xx    ⋯ 10+ years  MORTGAGE       NA
# 2 B3        Aug-2010   850xx    ⋯ 8 years    MORTGAGE       NA
# 3 B3        Jan-2009   852xx    ⋯ 10+ years  OTHER          NA
# 4 A4        Mar-2011   853xx    ⋯ 5 years    MORTGAGE       NA
# 5 C1        Jul-2011   856xx    ⋯ 5 years    MORTGAGE       NA
# 6 C3        Jun-2010   857xx    ⋯ < 1 year   111            NA
# ...
